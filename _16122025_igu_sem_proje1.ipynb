# %%
print('Merhaba Samet')
import sys
print(sys.version)
from google.colab import drive
drive.mount ('/content/drive')
import os
os.chdir('/content/drive/My Drive/_16122025_igu_sem_proje1')
# !pwd # ilk kod blogunun cıktısını bize veren bir kod blogudur.
# Out:
# Merhaba Samet
# 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/_16122025_igu_sem_proje1

# %% [markdown]
# # **16.12.2025 İGÜ SEM OTONOM EĞİTİMİ **
# *ABDULSAMET* **ÇAĞLAYAN**
#   google colab 1. örnek
